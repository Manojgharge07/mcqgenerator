# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain.chat_models import ChatOpenAI

# %%
# Python example
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
KEY=os.getenv("MY_API_KEY")
